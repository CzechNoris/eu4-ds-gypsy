# %% [markdown]
# # Analyze cProfile output

# %%
import pstats

profiler_output_file = '../output/cprofiler'

# Load the profiler output
stats = pstats.Stats(profiler_output_file)

# Print statistics
stats.sort_stats('cumulative')
stats.print_stats()
# Out:
# Mon Dec  4 12:42:39 2023    ../output/cprofiler
#
#          99502673 function calls (99483229 primitive calls) in 40.667 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     162/1    0.000    0.000   40.667   40.667 {built-in method builtins.exec}
#         1    2.905    2.905   40.667   40.667 ./scripts/gen_builds.py:1(<module>)
#    483091    4.870    0.000   35.785    0.000 ./scripts/gen_builds.py:532(expanded_build)
#    483091    4.675    0.000   19.601    0.000 ./scripts/gen_builds.py:555(update_policies)
#   2898546    0.788    0.000    9.704    0.000 ./scripts/gen_builds.py:480(deepcopy)
#   2898546    7.854    0.000    7.854    0.000 {built-in method _pickle.loads}
#   4550875    3.597    0.000    5.801    0.000 /opt/homebrew/Cellar/python@3.10/3.10.13/Frameworks/Python.framework/Versions/3.10/lib/python3.10/collections/__init__.py:640(update)
# ...
